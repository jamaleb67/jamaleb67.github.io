# %% [markdown]
# # Lab 2 - Fun with Data Structures
#
# We are going to pull in a dataset that we are unfamiliar with in order to explore it and organize subsets of the data into python data structures.
#
# We will use the crossref.org API to query academic research publications.
# https://www.crossref.org/documentation/retrieve-metadata/rest-api/a-non-technical-introduction-to-our-api/
#
# Use your last name in the query to generate different results from the rest of the class.

# %%
import requests

name='mcgee'  # use your last name for the query
rows='100'    # only request the first 100 results

url='https://api.crossref.org/works?filter=has-license:true,has-full-text:true&query.author='+name+'&rows='+rows

response=requests.get(url)  # use the requests module to get the results

# %% [markdown]
# Verify that the request was successful.  Html status code of 200 means successful.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Investigate the type of data returned by the response.  This is a requests response object.

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# Because the data is json, we can use the requests method to convert the json data to a python dictionary.

# %%
resp = response.json()
type(resp)
# Out:
# dict

# %% [markdown]
# Look at the contents of the data.

# %%
resp
# Out:
# {'status': 'ok',
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'message': {'facets': {},
#   'total-results': 5976,
#   'items': [{'indexed': {'date-parts': [[2022, 6, 6]],
#      'date-time': '2022-06-06T07:51:06Z',
#      'timestamp': 1654501866398},
#     'reference-count': 39,
#     'publisher': 'Elsevier BV',
#     'license': [{'start': {'date-parts': [[2016, 6, 1]],
#        'date-time': '2016-06-01T00:00:00Z',
#        'timestamp': 1464739200000},
#       'content-version': 'tdm',
#       'delay-in-days': 0,
#       'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#     'content-domain': {'domain': ['elsevier.com', 'sciencedirect.com'],
#      'crossmark-restriction': True},
#     'short-container-title': ['Journal of Economic Behavior &amp; Organization'],
#     'published-print': {'date-parts': [[2016, 6]]},
#     'DOI': '10.1016/j.jebo.2016.03.001',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2016, 3, 22]],
#      'date-time': '2016-03-22T14:07:20Z',
#      'timestamp': 1458655640000},
#     'page': '89-101',
#     'update-policy': 'http://dx.doi.org/10.1016/elsevier_cm_policy',
#     'source': 'Crossref',
#     'is-referenced-by-count': 24,
#     'title': ['Search, effort, and locus of control'],
#     'prefix': '10.1016',
#     'volume': '126',
#     'author': [{'given': 'Andrew',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []},
#      {'ORCID': 'http://orcid.org/0000-0002-1059-9286',
#       'authenticated-orcid': False,
#       'given': 'Peter',
#       'family': 'McGee',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '78',
#     'reference': [{'key': '10.1016/j.jebo.2016.03.001_bib0005',
#       'series-title': 'Learning About Job Search: A Field Experiment With Job Seekers in Germany',
#       'author': 'Altmann',
#       'year': '2015'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0010',
#       'doi-asserted-by': 'crossref',
#       'first-page': '308',
#       'DOI': '10.2307/145493',
#       'article-title': 'Internal–external attitudes personal initiative, and the labor market experience of black and white men',
#       'volume': '12',
#       'author': 'Andrisani',
#       'year': '1977',
#       'journal-title': 'J. Hum. Resour.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0015',
#       'doi-asserted-by': 'crossref',
#       'first-page': '658',
#       'DOI': '10.2307/145241',
#       'article-title': 'Internal–external attitudes, sense of efficacy, and labor market experience: a reply to Duncan and Morgan',
#       'author': 'Andrisani',
#       'year': '1981',
#       'journal-title': 'J. Hum. Resour.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0020',
#       'series-title': "Are Young People's Educational Outcomes Linked to Their Sense of Control?",
#       'author': 'Baron',
#       'year': '2010'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0025',
#       'doi-asserted-by': 'crossref',
#       'first-page': '453',
#       'DOI': '10.1146/annurev-economics-080511-110922',
#       'article-title': 'The relationship between economic preferences and psychological personality measures',
#       'volume': '4',
#       'author': 'Becker',
#       'year': '2012',
#       'journal-title': 'Annu. Rev. Econ.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0030',
#       'doi-asserted-by': 'crossref',
#       'first-page': '103',
#       'DOI': '10.1006/reec.1997.0158',
#       'article-title': 'Unemployment, discouraged workers and female labour supply',
#       'volume': '52',
#       'author': 'Blundell',
#       'year': '1998',
#       'journal-title': 'Res. Econ.'},
#      {'issue': '4',
#       'key': '10.1016/j.jebo.2016.03.001_bib0035',
#       'doi-asserted-by': 'crossref',
#       'first-page': '815',
#       'DOI': '10.3368/jhr.43.4.815',
#       'article-title': 'Interpersonal styles and labor market outcomes',
#       'volume': '43',
#       'author': 'Borghans',
#       'year': '2008',
#       'journal-title': 'J. Hum. Resour.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0040',
#       'doi-asserted-by': 'crossref',
#       'first-page': '155',
#       'DOI': '10.1257/aer.91.2.155',
#       'article-title': 'Incentive-enhancing preferences: personality, behavior and earnings',
#       'volume': '91',
#       'author': 'Bowles',
#       'year': '2001',
#       'journal-title': 'Am. Econ. Assoc. Pap. Proc.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0045',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1',
#       'DOI': '10.1111/j.1465-7295.1981.tb00600.x',
#       'article-title': 'Economic search: an experimental study',
#       'volume': '19',
#       'author': 'Braunstein',
#       'year': '1981',
#       'journal-title': 'Econ. Inq.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0050',
#       'doi-asserted-by': 'crossref',
#       'first-page': '133',
#       'DOI': '10.1111/j.1465-7295.1982.tb01146.x',
#       'article-title': 'Labor market search: an experimental study',
#       'volume': '20',
#       'author': 'Braunstein',
#       'year': '1982',
#       'journal-title': 'Econ. Inq.'},
#      {'issue': '2',
#       'key': '10.1016/j.jebo.2016.03.001_bib0055',
#       'doi-asserted-by': 'crossref',
#       'first-page': '948',
#       'DOI': '10.1257/aer.101.2.948',
#       'article-title': 'Real-time search in the laboratory and the market',
#       'volume': '101',
#       'author': 'Brown',
#       'year': '2011',
#       'journal-title': 'Am. Econ. Rev.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0060',
#       'article-title': 'Ranks of discouraged workers and others marginally attached to the labor force rise during recession',
#       'author': 'Bureau of Labor Statistics',
#       'year': '2009',
#       'journal-title': 'Issues Labor Stat.'},
#      {'issue': '1',
#       'key': '10.1016/j.jebo.2016.03.001_bib0065',
#       'doi-asserted-by': 'crossref',
#       'first-page': '88',
#       'DOI': '10.1162/REST_a_00459',
#       'article-title': 'Locus of control and job search strategies',
#       'volume': '97',
#       'author': 'Caliendo',
#       'year': '2015',
#       'journal-title': 'Rev. Econ. Stat.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0070',
#       'series-title': 'Microeconometrics: Methods and Applications',
#       'author': 'Cameron',
#       'year': '2005'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0075',
#       'series-title': 'Handbook of Labor Economics',
#       'doi-asserted-by': 'crossref',
#       'first-page': '229',
#       'DOI': '10.1016/S0169-7218(11)00409-6',
#       'article-title': 'Lab labor: what can labor economists learn from the lab?',
#       'author': 'Charness',
#       'year': '2011'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0080',
#       'series-title': 'Two Economists’ Musings on the Stability of Locus of Control',
#       'author': 'Cobb-Clark',
#       'year': '2011'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0085',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1',
#       'DOI': '10.1016/j.jebo.2013.10.011',
#       'article-title': 'Healthy habits: the connection between diet, exercise, and locus of control',
#       'volume': '98',
#       'author': 'Cobb-Clark',
#       'year': '2014',
#       'journal-title': 'J. Econ. Behav. Organ.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0090',
#       'doi-asserted-by': 'crossref',
#       'first-page': '701',
#       'DOI': '10.2307/1558773',
#       'article-title': 'An economic model of locus of control and the human capital investment decision',
#       'volume': '38',
#       'author': 'Coleman',
#       'year': '2003',
#       'journal-title': 'J. Hum. Resour.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0095',
#       'doi-asserted-by': 'crossref',
#       'first-page': '301',
#       'DOI': '10.1007/BF00209391',
#       'article-title': 'Laboratory experiments with a finite horizon job-search model',
#       'volume': '2',
#       'author': 'Cox',
#       'year': '1989',
#       'journal-title': 'J. Risk Uncertain.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0100',
#       'series-title': 'The Effects of a Re-Entry Program on Locus of Control and Self-Regard',
#       'author': 'Dextraze',
#       'year': '1986'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0105',
#       'doi-asserted-by': 'crossref',
#       'first-page': '379',
#       'DOI': '10.2466/pr0.1977.41.2.379',
#       'article-title': 'Effects of manipulation on examination of grades on locus of control beliefs',
#       'volume': '41',
#       'author': 'Doyle',
#       'year': '1977',
#       'journal-title': 'Psychol. Rep.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0110',
#       'doi-asserted-by': 'crossref',
#       'first-page': '352',
#       'DOI': '10.1037/0021-9010.78.3.352',
#       'article-title': 'Self-efficacy training to speed reemployment: helping people to help themselves',
#       'volume': '78',
#       'author': 'Eden',
#       'year': '1993',
#       'journal-title': 'J. Appl. Psychol.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0115',
#       'doi-asserted-by': 'crossref',
#       'first-page': '399',
#       'DOI': '10.1016/S0927-5371(03)00050-2',
#       'article-title': 'Why labour market experiments?',
#       'volume': '10',
#       'author': 'Falk',
#       'year': '2003',
#       'journal-title': 'Labour Econ.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0120',
#       'series-title': 'Do I Have What It Takes? Equilibrium Search With Type Uncertainty and Non-Participation',
#       'author': 'Falk',
#       'year': '2006'},
#      {'issue': '4',
#       'key': '10.1016/j.jebo.2016.03.001_bib0125',
#       'doi-asserted-by': 'crossref',
#       'first-page': '25',
#       'DOI': '10.1257/089533005775196732',
#       'article-title': 'Cognitive reflection and decision making',
#       'volume': '19',
#       'author': 'Frederick',
#       'year': '2005',
#       'journal-title': 'J. Econ. Perspect.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0130',
#       'doi-asserted-by': 'crossref',
#       'first-page': '26',
#       'DOI': '10.1037/1040-3590.4.1.26',
#       'article-title': 'The development of markers for the Big-Five factor structure',
#       'volume': '4',
#       'author': 'Goldberg',
#       'year': '1992',
#       'journal-title': 'Psychol. Assess.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0135',
#       'doi-asserted-by': 'crossref',
#       'first-page': '815',
#       'DOI': '10.1111/j.1465-7295.1997.tb01966.x',
#       'article-title': 'The impact of psychological and human capital on wages',
#       'volume': '35',
#       'author': 'Goldsmith',
#       'year': '1997',
#       'journal-title': 'Econ. Inq.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0140',
#       'doi-asserted-by': 'crossref',
#       'first-page': '411',
#       'DOI': '10.1086/504455',
#       'article-title': 'The effects of cognitive and noncognitive abilities on labor market outcomes and social behavior',
#       'volume': '24',
#       'author': 'Heckman',
#       'year': '2006',
#       'journal-title': 'J. Labor Econ.'},
#      {'issue': '5',
#       'key': '10.1016/j.jebo.2016.03.001_bib0145',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1644',
#       'DOI': '10.1257/000282802762024700',
#       'article-title': 'Risk aversion and incentive effects',
#       'volume': '92',
#       'author': 'Holt',
#       'year': '2002',
#       'journal-title': 'Am. Econ. Rev.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0150',
#       'series-title': 'The College Type: Personality and Educational Inequality',
#       'author': 'Lundberg',
#       'year': '2013'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0155',
#       'doi-asserted-by': 'crossref',
#       'first-page': '184',
#       'DOI': '10.1177/0019793914556245',
#       'article-title': 'How the perception of control influences unemployed job search',
#       'volume': '68',
#       'author': 'McGee',
#       'year': '2015',
#       'journal-title': 'Ind. Labor Relat. Rev.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0160',
#       'series-title': 'Search, Effort, and Locus of Control',
#       'author': 'McGee',
#       'year': '2011'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0165',
#       'doi-asserted-by': 'crossref',
#       'first-page': '827',
#       'DOI': '10.1016/j.joep.2005.03.001',
#       'article-title': 'How important is your personality? Labor market returns to personality for women in the US and UK',
#       'volume': '26',
#       'author': 'Osborne-Groves',
#       'year': '2005',
#       'journal-title': 'J. Econ. Psychol.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0170',
#       'doi-asserted-by': 'crossref',
#       'article-title': 'Maintaining (Locus of) control? Data combination for the identification and inference of factor structure models',
#       'author': 'Piatek',
#       'year': '2015',
#       'journal-title': 'J. Appl. Econ.',
#       'DOI': '10.1002/jae.2456'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0175',
#       'series-title': 'Society and the Adolescent Self-Image',
#       'author': 'Rosenberg',
#       'year': '1965'},
#      {'issue': '1',
#       'key': '10.1016/j.jebo.2016.03.001_bib0180',
#       'doi-asserted-by': 'crossref',
#       'DOI': '10.1037/h0092976',
#       'article-title': 'Generalized expectancies for internal versus external control of reinforcement',
#       'volume': '80',
#       'author': 'Rotter',
#       'year': '1966',
#       'journal-title': 'Psychol. Monogr. Gen. Appl.'},
#      {'key': '10.1016/j.jebo.2016.03.001_bib0185',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1063',
#       'DOI': '10.1037/0022-3514.67.6.1063',
#       'article-title': 'Distinguishing optimism from neuroticism (and trait anxiety, self-mastery, and self-esteem): a re-evaluation of the life orientation test',
#       'volume': '67',
#       'author': 'Scheier',
#       'year': '1994',
#       'journal-title': 'J. Personal. Soc. Psychol.'},
#      {'issue': '2',
#       'key': '10.1016/j.jebo.2016.03.001_bib0190',
#       'doi-asserted-by': 'crossref',
#       'first-page': '249',
#       'DOI': '10.1177/001979397402700207',
#       'article-title': 'The persistence of the discouraged worker effect',
#       'volume': '27',
#       'author': 'Schweitzer',
#       'year': '1974',
#       'journal-title': 'Ind. Labor Relat. Rev.'},
#      {'issue': '6',
#       'key': '10.1016/j.jebo.2016.03.001_bib0195',
#       'doi-asserted-by': 'crossref',
#       'first-page': '685',
#       'DOI': '10.1037/h0056432',
#       'article-title': 'The personnel test: a restandardized abridgement of the Otis S-A test for business and industrial use',
#       'volume': '23',
#       'author': 'Wonderlic',
#       'year': '1939',
#       'journal-title': 'J. Appl. Psychol.'}],
#     'container-title': ['Journal of Economic Behavior &amp; Organization'],
#     'language': 'en',
#     'link': [{'URL': 'https://api.elsevier.com/content/article/PII:S016726811630004X?httpAccept=text/xml',
#       'content-type': 'text/xml',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://api.elsevier.com/content/article/PII:S016726811630004X?httpAccept=text/plain',
#       'content-type': 'text/plain',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'}],
#     'deposited': {'date-parts': [[2018, 9, 14]],
#      'date-time': '2018-09-14T00:55:30Z',
#      'timestamp': 1536886530000},
#     'score': 14.665423,
#     'resource': {'primary': {'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S016726811630004X'}},
#     'issued': {'date-parts': [[2016, 6]]},
#     'references-count': 39,
#     'alternative-id': ['S016726811630004X'],
#     'URL': 'http://dx.doi.org/10.1016/j.jebo.2016.03.001',
#     'ISSN': ['0167-2681'],
#     'issn-type': [{'value': '0167-2681', 'type': 'print'}],
#     'subject': ['Organizational Behavior and Human Resource Management',
#      'Economics and Econometrics'],
#     'published': {'date-parts': [[2016, 6]]},
#     'assertion': [{'value': 'Elsevier',
#       'name': 'publisher',
#       'label': 'This article is maintained by'},
#      {'value': 'Search, effort, and locus of control',
#       'name': 'articletitle',
#       'label': 'Article Title'},
#      {'value': 'Journal of Economic Behavior & Organization',
#       'name': 'journaltitle',
#       'label': 'Journal Title'},
#      {'value': 'https://doi.org/10.1016/j.jebo.2016.03.001',
#       'name': 'articlelink',
#       'label': 'CrossRef DOI link to publisher maintained version'},
#      {'value': 'article', 'name': 'content_type', 'label': 'Content Type'},
#      {'value': '© 2016 Elsevier B.V. All rights reserved.',
#       'name': 'copyright',
#       'label': 'Copyright'}]},
#    {'indexed': {'date-parts': [[2022, 5, 31]],
#      'date-time': '2022-05-31T10:13:08Z',
#      'timestamp': 1653991988780},
#     'reference-count': 48,
#     'publisher': 'Wiley',
#     'issue': '4',
#     'license': [{'start': {'date-parts': [[2019, 6, 18]],
#        'date-time': '2019-06-18T00:00:00Z',
#        'timestamp': 1560816000000},
#       'content-version': 'vor',
#       'delay-in-days': 0,
#       'URL': 'http://onlinelibrary.wiley.com/termsAndConditions#vor'},
#      {'start': {'date-parts': [[2019, 6, 18]],
#        'date-time': '2019-06-18T00:00:00Z',
#        'timestamp': 1560816000000},
#       'content-version': 'tdm',
#       'delay-in-days': 0,
#       'URL': 'http://doi.wiley.com/10.1002/tdm_license_1.1'}],
#     'funder': [{'DOI': '10.13039/501100004326',
#       'name': 'Simon Fraser University',
#       'doi-asserted-by': 'publisher'},
#      {'DOI': '10.13039/100007756',
#       'name': 'University of Arkansas',
#       'doi-asserted-by': 'publisher'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Econ Inq'],
#     'published-print': {'date-parts': [[2019, 10]]},
#     'DOI': '10.1111/ecin.12816',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2019, 6, 18]],
#      'date-time': '2019-06-18T12:36:18Z',
#      'timestamp': 1560861378000},
#     'page': '2125-2146',
#     'source': 'Crossref',
#     'is-referenced-by-count': 2,
#     'title': ['AFTER THE TOURNAMENT: OUTCOMES AND EFFORT PROVISION'],
#     'prefix': '10.1111',
#     'volume': '57',
#     'author': [{'given': 'Andrew',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': [{'name': 'Department of EconomicsUniversity of Alberta Edmonton AB T6G 2H4 Canada'}]},
#      {'given': 'Peter',
#       'family': 'McGee',
#       'sequence': 'additional',
#       'affiliation': [{'name': 'Department of EconomicsUniversity of Arkansas Fayetteville AR 72701'}]}],
#     'member': '311',
#     'published-online': {'date-parts': [[2019, 6, 18]]},
#     'reference': [{'key': 'e_1_2_8_2_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.2307/2937787'},
#      {'key': 'e_1_2_8_3_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1086/662130'},
#      {'key': 'e_1_2_8_4_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.geb.2011.06.009'},
#      {'key': 'e_1_2_8_5_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1257/aer.90.1.166'},
#      {'key': 'e_1_2_8_6_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1111/j.1468-0297.2005.01032.x'},
#      {'key': 'e_1_2_8_7_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1287/mnsc.2015.2321'},
#      {'key': 'e_1_2_8_8_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1287/mnsc.2015.2257'},
#      {'key': 'e_1_2_8_9_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.3368/jhr.50.2.317'},
#      {'key': 'e_1_2_8_10_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1162/003355302760193904'},
#      {'key': 'e_1_2_8_11_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1006/game.1998.0709'},
#      {'key': 'e_1_2_8_12_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1007/s10683-014-9421-0'},
#      {'key': 'e_1_2_8_13_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.geb.2016.12.002'},
#      {'key': 'e_1_2_8_14_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.geb.2003.06.003'},
#      {'key': 'e_1_2_8_15_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.econlet.2014.01.042'},
#      {'key': 'e_1_2_8_16_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1162/003355399556151'},
#      {'key': 'e_1_2_8_17_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1007/s10683-006-9159-4'},
#      {'key': 'e_1_2_8_18_1',
#       'volume-title': 'Counterproductive Work Behavior: Investigations of Actors and Targets',
#       'author': 'Fox S.',
#       'year': '2004'},
#      {'key': 'e_1_2_8_19_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1628/0932456041960560'},
#      {'key': 'e_1_2_8_20_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.3982/QE309'},
#      {'key': 'e_1_2_8_21_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.geb.2010.01.002'},
#      {'key': 'e_1_2_8_22_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1111/j.1430-9134.2005.00039.x'},
#      {'key': 'e_1_2_8_23_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1086/674409'},
#      {'key': 'e_1_2_8_24_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1086/467773'},
#      {'key': 'e_1_2_8_25_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1006/game.1994.1056'},
#      {'key': 'e_1_2_8_26_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1257/000282802762024700'},
#      {'key': 'e_1_2_8_27_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1073/pnas.0502399102'},
#      {'key': 'e_1_2_8_28_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1002/soej.12115'},
#      {'key': 'e_1_2_8_29_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1002/job.563'},
#      {'issue': '4',
#       'key': 'e_1_2_8_30_1',
#       'first-page': '728',
#       'article-title': 'Fairness as a Constraint on Profit Seeking: Entitlement in the Market',
#       'volume': '76',
#       'author': 'Kahneman D.',
#       'year': '1986',
#       'journal-title': 'American Economic Review'},
#      {'key': 'e_1_2_8_31_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1257/mic.3.3.86'},
#      {'key': 'e_1_2_8_32_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.jebo.2007.08.002'},
#      {'key': 'e_1_2_8_33_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1007/s11238-009-9189-4'},
#      {'key': 'e_1_2_8_34_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1108/02683940110391517'},
#      {'key': 'e_1_2_8_35_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1257/aer.90.2.426'},
#      {'key': 'e_1_2_8_36_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1162/qjec.121.3.783'},
#      {'key': 'e_1_2_8_37_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.2307/3003535'},
#      {'key': 'e_1_2_8_38_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1086/298022'},
#      {'key': 'e_1_2_8_39_1',
#       'first-page': '1281',
#       'article-title': 'Incorporating Fairness into Game Theory and Economics',
#       'volume': '83',
#       'author': 'Rabin M.',
#       'year': '1993',
#       'journal-title': 'American Economic Review'},
#      {'issue': '4',
#       'key': 'e_1_2_8_40_1',
#       'first-page': '701',
#       'article-title': 'Prizes and Incentives in Elimination Tournaments',
#       'volume': '76',
#       'author': 'Rosen S.',
#       'year': '1986',
#       'journal-title': 'American Economic Review'},
#      {'key': 'e_1_2_8_41_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.obhdp.2004.01.001'},
#      {'key': 'e_1_2_8_42_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1111/j.0965-075X.2004.00271.x'},
#      {'key': 'e_1_2_8_43_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.2307/2118480'},
#      {'key': 'e_1_2_8_44_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1037/0021-9010.77.4.511'},
#      {'key': 'e_1_2_8_45_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1037/0021-9010.82.3.434'},
#      {'key': 'e_1_2_8_46_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1037/0021-9010.92.3.840'},
#      {'key': 'e_1_2_8_47_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/S0167-4870(02)00083-1'},
#      {'key': 'e_1_2_8_48_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1016/j.joep.2009.07.002'},
#      {'key': 'e_1_2_8_49_1',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1023/A:1009592430712'}],
#     'container-title': ['Economic Inquiry'],
#     'language': 'en',
#     'link': [{'URL': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1111%2Fecin.12816',
#       'content-type': 'application/pdf',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://onlinelibrary.wiley.com/doi/pdf/10.1111/ecin.12816',
#       'content-type': 'application/pdf',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://onlinelibrary.wiley.com/doi/full-xml/10.1111/ecin.12816',
#       'content-type': 'application/xml',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://onlinelibrary.wiley.com/doi/pdf/10.1111/ecin.12816',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 9, 25]],
#      'date-time': '2019-09-25T17:18:10Z',
#      'timestamp': 1569431890000},
#     'score': 14.6436405,
#     'resource': {'primary': {'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/ecin.12816'}},
#     'issued': {'date-parts': [[2019, 6, 18]]},
#     'references-count': 48,
#     'journal-issue': {'issue': '4',
#      'published-online': {'date-parts': [[2019, 4, 30]]},
#      'published-print': {'date-parts': [[2019, 10]]}},
#     'alternative-id': ['10.1111/ecin.12816'],
#     'URL': 'http://dx.doi.org/10.1111/ecin.12816',
#     'archive': ['Portico'],
#     'ISSN': ['0095-2583', '1465-7295'],
#     'issn-type': [{'value': '0095-2583', 'type': 'print'},
#      {'value': '1465-7295', 'type': 'electronic'}],
#     'subject': ['Economics and Econometrics',
#      'General Business, Management and Accounting'],
#     'published': {'date-parts': [[2019, 6, 18]]}},
#    {'indexed': {'date-parts': [[2022, 3, 30]],
#      'date-time': '2022-03-30T16:09:44Z',
#      'timestamp': 1648656584579},
#     'reference-count': 19,
#     'publisher': 'Cambridge University Press (CUP)',
#     'issue': '1',
#     'license': [{'start': {'date-parts': [[2016, 5, 17]],
#        'date-time': '2016-05-17T00:00:00Z',
#        'timestamp': 1463443200000},
#       'content-version': 'unspecified',
#       'delay-in-days': 6652,
#       'URL': 'https://www.cambridge.org/core/terms'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Polit. life sci.'],
#     'published-print': {'date-parts': [[1998, 3]]},
#     'DOI': '10.1017/s0730938400025284',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2017, 2, 8]],
#      'date-time': '2017-02-08T06:28:33Z',
#      'timestamp': 1486535313000},
#     'page': '26-29',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Nuclear Meltdown: Ethics of the Need to Transfer Genes'],
#     'prefix': '10.1017',
#     'volume': '17',
#     'author': [{'given': 'Glenn',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Daniel B.',
#       'family': 'McGee',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '56',
#     'published-online': {'date-parts': [[2016, 5, 17]]},
#     'reference': [{'key': 'S0730938400025284_ref6',
#       'unstructured': "Erdrich L. (1993). “A Woman's Work.” Harper's Magazine (May):35–46."},
#      {'key': 'S0730938400025284_ref4',
#       'volume-title': "Am I My Brother's Keeper?",
#       'author': 'Caplan',
#       'year': '1998'},
#      {'key': 'S0730938400025284_ref11',
#       'volume-title': 'The Perfect Baby: A Pragmatic Approach to Genetics.',
#       'author': 'McGee',
#       'year': '1997b'},
#      {'key': 'S0730938400025284_ref8',
#       'unstructured': "King W. (1995). “Law Can't Stop Abuse, Infertility Doctors Say.” Seattle Times (October 10):B1."},
#      {'key': 'S0730938400025284_ref5',
#       'volume-title': 'Middletown Families: Fifty Years of Change and Continuity.',
#       'author': 'Caplow',
#       'year': '1982'},
#      {'key': 'S0730938400025284_ref17',
#       'volume-title': 'Community and Society (Gemeinschaft und Gesellschaft).',
#       'author': 'Toennies',
#       'year': '1957'},
#      {'key': 'S0730938400025284_ref12',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1093/humrep/12.3.407'},
#      {'key': 'S0730938400025284_ref10',
#       'first-page': '17',
#       'article-title': '“Parenting in an Era of Genetics.”',
#       'volume': '27',
#       'author': 'McGee',
#       'year': '1997a',
#       'journal-title': 'Hastings Center Report'},
#      {'key': 'S0730938400025284_ref19',
#       'unstructured': "Wozencraft A. (1996). “It's a Baby or It's Your Money Back.” New York Times (August 25):B1."},
#      {'key': 'S0730938400025284_ref9',
#       'volume-title': 'Faith, Life, and Witness.',
#       'author': 'McGee',
#       'year': '1990'},
#      {'key': 'S0730938400025284_ref16',
#       'volume-title': 'Children of Choice.',
#       'author': 'Robertson',
#       'year': '1994'},
#      {'key': 'S0730938400025284_ref18',
#       'volume-title': 'The Ethics of Human Gene Therapy.',
#       'author': 'Walters',
#       'year': '1997'},
#      {'key': 'S0730938400025284_ref1',
#       'first-page': '623',
#       'article-title': '“Alternative Reproduction.”',
#       'volume': '65',
#       'author': 'Andrews',
#       'year': '1991',
#       'journal-title': 'Southern California Law Review'},
#      {'key': 'S0730938400025284_ref13',
#       'volume-title': 'Send in the Clones.',
#       'author': 'McGee',
#       'year': '1998'},
#      {'key': 'S0730938400025284_ref7',
#       'article-title': '“The Wisdom of Repugnance.”',
#       'volume': '52',
#       'author': 'Kass',
#       'year': '1997',
#       'journal-title': 'New Republic'},
#      {'key': 'S0730938400025284_ref2',
#       'doi-asserted-by': 'publisher',
#       'DOI': '10.1146/annurev.so.09.080183.001331'},
#      {'key': 'S0730938400025284_ref15',
#       'volume-title': 'The Little Community: Viewpoints for the Study of the Human Whole.',
#       'author': 'Redfield',
#       'year': '1955'},
#      {'key': 'S0730938400025284_ref3',
#       'unstructured': 'Brock D. (1996). “Justice and Normalcy in Infertility Treatments.” Paper delivered to American Association of Bioethics Annual Meeting, San Francisco, CA, November.'},
#      {'key': 'S0730938400025284_ref14',
#       'volume-title': 'The Gene Mystique.',
#       'author': 'Nelkin',
#       'year': '1994'}],
#     'container-title': ['Politics and the Life Sciences'],
#     'language': 'en',
#     'link': [{'URL': 'https://www.cambridge.org/core/services/aop-cambridge-core/content/view/S0730938400025284',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 4, 11]],
#      'date-time': '2019-04-11T16:40:24Z',
#      'timestamp': 1555000824000},
#     'score': 14.151274,
#     'resource': {'primary': {'URL': 'https://www.cambridge.org/core/product/identifier/S0730938400025284/type/journal_article'}},
#     'issued': {'date-parts': [[1998, 3]]},
#     'references-count': 19,
#     'journal-issue': {'issue': '1',
#      'published-print': {'date-parts': [[1998, 3]]}},
#     'alternative-id': ['S0730938400025284'],
#     'URL': 'http://dx.doi.org/10.1017/s0730938400025284',
#     'ISSN': ['0730-9384', '1471-5457'],
#     'issn-type': [{'value': '0730-9384', 'type': 'print'},
#      {'value': '1471-5457', 'type': 'electronic'}],
#     'subject': ['Public Administration',
#      'Social Sciences (miscellaneous)',
#      'Sociology and Political Science'],
#     'published': {'date-parts': [[1998, 3]]}},
#    {'indexed': {'date-parts': [[2022, 3, 31]],
#      'date-time': '2022-03-31T18:38:08Z',
#      'timestamp': 1648751888979},
#     'reference-count': 3,
#     'publisher': 'Wiley',
#     'issue': '4',
#     'license': [{'start': {'date-parts': [[2015, 9, 1]],
#        'date-time': '2015-09-01T00:00:00Z',
#        'timestamp': 1441065600000},
#       'content-version': 'tdm',
#       'delay-in-days': 1632,
#       'URL': 'http://doi.wiley.com/10.1002/tdm_license_1.1'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[2011, 4]]},
#     'DOI': '10.1111/j.1600-6143.2011.03459.x',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2011, 3, 15]],
#      'date-time': '2011-03-15T02:01:26Z',
#      'timestamp': 1300154486000},
#     'page': '871-872',
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['A Picture Is Worth a Thousand Words'],
#     'prefix': '10.1111',
#     'volume': '11',
#     'author': [{'given': 'R. G.',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'L. M.',
#       'family': 'McGee',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '311',
#     'published-online': {'date-parts': [[2011, 3, 14]]},
#     'reference': [{'key': '10.1111/j.1600-6143.2011.03459.x-BIB1|cit1',
#       'doi-asserted-by': 'crossref',
#       'first-page': '49',
#       'DOI': '10.1145/1374489.1374501',
#       'article-title': 'Tag clouds and the case for vernacular visualization',
#       'volume': '15',
#       'author': 'Viégas',
#       'year': '2008',
#       'journal-title': 'Interactions'},
#      {'key': '10.1111/j.1600-6143.2011.03459.x-BIB2|cit2',
#       'unstructured': 'Thomson Reuters ISI Web of Knowledge [Internet] http://www.isiwebofknowledge.com/'},
#      {'key': '10.1111/j.1600-6143.2011.03459.x-BIB3|cit3',
#       'unstructured': 'Hardy Leung Tagxedo-Creator [Internet] http://www.tagxedo.com/app.html'}],
#     'container-title': ['American Journal of Transplantation'],
#     'language': 'en',
#     'link': [{'URL': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1111%2Fj.1600-6143.2011.03459.x',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'http://onlinelibrary.wiley.com/wol1/doi/10.1111/j.1600-6143.2011.03459.x/fullpdf',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2021, 7, 7]],
#      'date-time': '2021-07-07T13:55:53Z',
#      'timestamp': 1625666153000},
#     'score': 13.708644,
#     'resource': {'primary': {'URL': 'https://onlinelibrary.wiley.com/doi/10.1111/j.1600-6143.2011.03459.x'}},
#     'subtitle': ['A Picture Is Worth a Thousand Words'],
#     'issued': {'date-parts': [[2011, 3, 14]]},
#     'references-count': 3,
#     'journal-issue': {'issue': '4',
#      'published-print': {'date-parts': [[2011, 4]]}},
#     'URL': 'http://dx.doi.org/10.1111/j.1600-6143.2011.03459.x',
#     'ISSN': ['1600-6135'],
#     'issn-type': [{'value': '1600-6135', 'type': 'print'}],
#     'subject': ['Pharmacology (medical)',
#      'Transplantation',
#      'Immunology and Allergy'],
#     'published': {'date-parts': [[2011, 3, 14]]}},
#    {'indexed': {'date-parts': [[2022, 4, 18]],
#      'date-time': '2022-04-18T12:31:07Z',
#      'timestamp': 1650285067572},
#     'reference-count': 9,
#     'publisher': 'Elsevier BV',
#     'license': [{'start': {'date-parts': [[2015, 3, 1]],
#        'date-time': '2015-03-01T00:00:00Z',
#        'timestamp': 1425168000000},
#       'content-version': 'tdm',
#       'delay-in-days': 0,
#       'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#     'content-domain': {'domain': ['elsevier.com', 'sciencedirect.com'],
#      'crossmark-restriction': True},
#     'short-container-title': ['Economics Letters'],
#     'published-print': {'date-parts': [[2015, 3]]},
#     'DOI': '10.1016/j.econlet.2015.01.004',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2015, 1, 13]],
#      'date-time': '2015-01-13T22:46:33Z',
#      'timestamp': 1421189193000},
#     'page': '35-38',
#     'update-policy': 'http://dx.doi.org/10.1016/elsevier_cm_policy',
#     'source': 'Crossref',
#     'is-referenced-by-count': 19,
#     'title': ['Performance pay, competitiveness, and the gender wage gap: Evidence from the United States'],
#     'prefix': '10.1016',
#     'volume': '128',
#     'author': [{'given': 'Andrew',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Peter',
#       'family': 'McGee',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Jessica',
#       'family': 'Pan',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '78',
#     'reference': [{'issue': '3',
#       'key': '10.1016/j.econlet.2015.01.004_br000005',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1409',
#       'DOI': '10.1093/qje/qju009',
#       'article-title': 'Gender, competitiveness, and career choices',
#       'volume': '129',
#       'author': 'Buser',
#       'year': '2014',
#       'journal-title': 'Quart. J. Econ.'},
#      {'issue': '11',
#       'key': '10.1016/j.econlet.2015.01.004_br000010',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1982',
#       'DOI': '10.1287/mnsc.1120.1542',
#       'article-title': 'Men, too, sometimes shy away from competition: the case of team competition',
#       'volume': '58',
#       'author': 'Dargnies',
#       'year': '2012',
#       'journal-title': 'Manage. Sci.'},
#      {'issue': '3',
#       'key': '10.1016/j.econlet.2015.01.004_br000015',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1049',
#       'DOI': '10.1162/00335530360698496',
#       'article-title': 'Performance in competitive environments: gender differences',
#       'volume': '118',
#       'author': 'Gneezy',
#       'year': '2003',
#       'journal-title': 'Quart. J. Econ.'},
#      {'issue': '4',
#       'key': '10.1016/j.econlet.2015.01.004_br000020',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1091',
#       'DOI': '10.1257/aer.104.4.1091',
#       'article-title': 'A grand gender convergence: its last chapter',
#       'volume': '104',
#       'author': 'Goldin',
#       'year': '2014',
#       'journal-title': 'Amer. Econ. Rev.'},
#      {'key': '10.1016/j.econlet.2015.01.004_br000025',
#       'doi-asserted-by': 'crossref',
#       'first-page': '410',
#       'DOI': '10.1086/261881',
#       'article-title': 'Wage inequality and the rise in returns to skill',
#       'volume': '101',
#       'author': 'Juhn',
#       'year': '1993',
#       'journal-title': 'J. Polit. Econ.'},
#      {'key': '10.1016/j.econlet.2015.01.004_br000030',
#       'doi-asserted-by': 'crossref',
#       'first-page': '701',
#       'DOI': '10.1016/j.joep.2009.03.006',
#       'article-title': 'Do gender differences in preferences for competition matter for occupational expectations?',
#       'volume': '30',
#       'author': 'Kleinjans',
#       'year': '2009',
#       'journal-title': 'J. Econ. Psychol.'},
#      {'issue': '1',
#       'key': '10.1016/j.econlet.2015.01.004_br000035',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1',
#       'DOI': '10.1162/qjec.2009.124.1.1',
#       'article-title': 'Performance pay and wage inequality',
#       'volume': '124',
#       'author': 'Lemieux',
#       'year': '2009',
#       'journal-title': 'Quart. J. Econ.'},
#      {'issue': '4',
#       'key': '10.1016/j.econlet.2015.01.004_br000040',
#       'doi-asserted-by': 'crossref',
#       'first-page': '681',
#       'DOI': '10.1177/001979391006300407',
#       'article-title': 'Understanding the gender pay gap: what’s competition got to do with it?',
#       'volume': '63',
#       'author': 'Manning',
#       'year': '2010',
#       'journal-title': 'Ind. Labor Relat. Rev.'},
#      {'issue': '3',
#       'key': '10.1016/j.econlet.2015.01.004_br000045',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1067',
#       'DOI': '10.1162/qjec.122.3.1067',
#       'article-title': 'Do women shy away from competition? Do men compete too much?',
#       'volume': '122',
#       'author': 'Niederle',
#       'year': '2007',
#       'journal-title': 'Quart. J. Econ.'}],
#     'container-title': ['Economics Letters'],
#     'language': 'en',
#     'link': [{'URL': 'https://api.elsevier.com/content/article/PII:S0165176515000142?httpAccept=text/xml',
#       'content-type': 'text/xml',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://api.elsevier.com/content/article/PII:S0165176515000142?httpAccept=text/plain',
#       'content-type': 'text/plain',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'}],
#     'deposited': {'date-parts': [[2018, 9, 26]],
#      'date-time': '2018-09-26T05:52:01Z',
#      'timestamp': 1537941121000},
#     'score': 13.616263,
#     'resource': {'primary': {'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0165176515000142'}},
#     'issued': {'date-parts': [[2015, 3]]},
#     'references-count': 9,
#     'alternative-id': ['S0165176515000142'],
#     'URL': 'http://dx.doi.org/10.1016/j.econlet.2015.01.004',
#     'ISSN': ['0165-1765'],
#     'issn-type': [{'value': '0165-1765', 'type': 'print'}],
#     'subject': ['Economics and Econometrics', 'Finance'],
#     'published': {'date-parts': [[2015, 3]]},
#     'assertion': [{'value': 'Elsevier',
#       'name': 'publisher',
#       'label': 'This article is maintained by'},
#      {'value': 'Performance pay, competitiveness, and the gender wage gap: Evidence from the United States',
#       'name': 'articletitle',
#       'label': 'Article Title'},
#      {'value': 'Economics Letters',
#       'name': 'journaltitle',
#       'label': 'Journal Title'},
#      {'value': 'https://doi.org/10.1016/j.econlet.2015.01.004',
#       'name': 'articlelink',
#       'label': 'CrossRef DOI link to publisher maintained version'},
#      {'value': 'article', 'name': 'content_type', 'label': 'Content Type'},
#      {'value': 'Copyright © 2015 Elsevier B.V. All rights reserved.',
#       'name': 'copyright',
#       'label': 'Copyright'}]},
#    {'indexed': {'date-parts': [[2022, 4, 3]],
#      'date-time': '2022-04-03T01:46:42Z',
#      'timestamp': 1648950402737},
#     'reference-count': 3,
#     'publisher': 'Springer Science and Business Media LLC',
#     'issue': '1',
#     'license': [{'start': {'date-parts': [[1979, 11, 1]],
#        'date-time': '1979-11-01T00:00:00Z',
#        'timestamp': 310262400000},
#       'content-version': 'tdm',
#       'delay-in-days': 0,
#       'URL': 'http://www.springer.com/tdm'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Soc'],
#     'published-print': {'date-parts': [[1979, 11]]},
#     'DOI': '10.1007/bf02701550',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2007, 9, 17]],
#      'date-time': '2007-09-17T21:27:18Z',
#      'timestamp': 1190064438000},
#     'page': '42-47',
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['The economics of conglomerate organization'],
#     'prefix': '10.1007',
#     'volume': '17',
#     'author': [{'given': 'Reece',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '297',
#     'reference': [{'key': 'BF02701550_CR1',
#       'doi-asserted-by': 'crossref',
#       'unstructured': 'Altbach, Philip G. “Publishing and the Intellectual System.”Annals of the American Academy of Political and Social Science, 421, 1975.',
#       'DOI': '10.1177/000271627542100101'},
#      {'key': 'BF02701550_CR2',
#       'doi-asserted-by': 'crossref',
#       'first-page': '4',
#       'DOI': '10.1207/s15328023top0504_1',
#       'volume': '5',
#       'author': 'P.W. Robinson',
#       'year': '1978',
#       'unstructured': 'Robinson, P.W. and Higbee, K.L. “Publishing a Textbook: Advice From Authors and Publishers.”Teaching of Psychology 5:4, December 1978.',
#       'journal-title': 'Teaching of Psychology'},
#      {'key': 'BF02701550_CR3',
#       'doi-asserted-by': 'crossref',
#       'unstructured': 'Whitten, Phillip. “College Textbook Publishing in the 1970s.”Annals of the American Academy of Political and Social Science, 421, 1975.',
#       'DOI': '10.1177/000271627542100107'}],
#     'container-title': ['Society'],
#     'language': 'en',
#     'link': [{'URL': 'http://link.springer.com/content/pdf/10.1007/BF02701550.pdf',
#       'content-type': 'application/pdf',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'http://link.springer.com/article/10.1007/BF02701550/fulltext.html',
#       'content-type': 'text/html',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'http://link.springer.com/content/pdf/10.1007/BF02701550',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 5, 21]],
#      'date-time': '2019-05-21T09:48:47Z',
#      'timestamp': 1558432127000},
#     'score': 13.232092,
#     'resource': {'primary': {'URL': 'http://link.springer.com/10.1007/BF02701550'}},
#     'issued': {'date-parts': [[1979, 11]]},
#     'references-count': 3,
#     'journal-issue': {'issue': '1',
#      'published-print': {'date-parts': [[1979, 11]]}},
#     'alternative-id': ['BF02701550'],
#     'URL': 'http://dx.doi.org/10.1007/bf02701550',
#     'ISSN': ['0147-2011', '1936-4725'],
#     'issn-type': [{'value': '0147-2011', 'type': 'print'},
#      {'value': '1936-4725', 'type': 'electronic'}],
#     'subject': ['General Social Sciences', 'Sociology and Political Science'],
#     'published': {'date-parts': [[1979, 11]]}},
#    {'indexed': {'date-parts': [[2022, 4, 3]],
#      'date-time': '2022-04-03T05:25:46Z',
#      'timestamp': 1648963546011},
#     'reference-count': 0,
#     'publisher': 'Wiley',
#     'issue': '4',
#     'license': [{'start': {'date-parts': [[2015, 9, 1]],
#        'date-time': '2015-09-01T00:00:00Z',
#        'timestamp': 1441065600000},
#       'content-version': 'tdm',
#       'delay-in-days': 2912,
#       'URL': 'http://doi.wiley.com/10.1002/tdm_license_1.1'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Natural Gas'],
#     'DOI': '10.1002/gas.3410050409',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2010, 7, 8]],
#      'date-time': '2010-07-08T11:25:29Z',
#      'timestamp': 1278588329000},
#     'page': '25-28',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Gas Marketing Issues in Exploration and Production Contracts'],
#     'prefix': '10.1002',
#     'volume': '5',
#     'author': [{'given': 'Becky',
#       'family': 'McGee',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '311',
#     'published-online': {'date-parts': [[2007, 9, 11]]},
#     'container-title': ['Natural Gas'],
#     'language': 'en',
#     'link': [{'URL': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fgas.3410050409',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://onlinelibrary.wiley.com/doi/full/10.1002/gas.3410050409',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2021, 7, 1]],
#      'date-time': '2021-07-01T18:30:29Z',
#      'timestamp': 1625164229000},
#     'score': 13.232092,
#     'resource': {'primary': {'URL': 'https://onlinelibrary.wiley.com/doi/10.1002/gas.3410050409'}},
#     'issued': {'date-parts': [[2007, 9, 11]]},
#     'references-count': 0,
#     'journal-issue': {'issue': '4'},
#     'URL': 'http://dx.doi.org/10.1002/gas.3410050409',
#     'ISSN': ['0743-5665'],
#     'issn-type': [{'value': '0743-5665', 'type': 'print'}],
#     'subject': ['General Earth and Planetary Sciences',
#      'General Environmental Science'],
#     'published': {'date-parts': [[2007, 9, 11]]}},
#    {'indexed': {'date-parts': [[2022, 4, 3]],
#      'date-time': '2022-04-03T03:01:12Z',
#      'timestamp': 1648954872455},
#     'reference-count': 0,
#     'publisher': 'Institute of Electrical and Electronics Engineers (IEEE)',
#     'issue': '10',
#     'license': [{'start': {'date-parts': [[1968, 1, 1]],
#        'date-time': '1968-01-01T00:00:00Z',
#        'timestamp': -63158400000},
#       'content-version': 'vor',
#       'delay-in-days': 0,
#       'URL': 'https://ieeexplore.ieee.org/Xplorehelp/downloads/license-information/IEEE.html'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Proc. IEEE'],
#     'published-print': {'date-parts': [[1968]]},
#     'DOI': '10.1109/proc.1968.6714',
#     'type': 'journal-article',
# ...
#       'doi-asserted-by': 'crossref',
#       'first-page': '241',
#       'DOI': '10.1001/jamainternmed.2013.12199',
#       'article-title': 'Sex-specific chest pain characteristics in the early diagnosis of acute myocardial infarction',
#       'volume': '174',
#       'author': 'Rubini Gimenez',
#       'year': '2013',
#       'journal-title': 'JAMA Intern Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib62',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1264',
#       'DOI': '10.1016/S0002-9149(02)02850-3',
#       'article-title': 'Usefulness of the response to sublingual nitroglycerin as a predictor of ischemic chest pain in the emergency department',
#       'volume': '90',
#       'author': 'Shry',
#       'year': '2002',
#       'journal-title': 'Am J Cardiol'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib63',
#       'doi-asserted-by': 'crossref',
#       'first-page': '979',
#       'DOI': '10.7326/0003-4819-139-12-200312160-00007',
#       'article-title': 'Chest pain relief by nitroglycerin does not predict active coronary artery disease',
#       'volume': '139',
#       'author': 'Henrikson',
#       'year': '2003',
#       'journal-title': 'Ann Intern Med'},
#      {'issue': '6',
#       'key': '10.1016/B978-0-323-39276-1.00049-4_bib64',
#       'doi-asserted-by': 'crossref',
#       'first-page': '581',
#       'DOI': '10.1016/j.annemergmed.2004.12.009',
#       'article-title': 'Changes in the numeric descriptive scale for pain after sublingual nitroglycerin do not predict cardiac etiology of chest pain',
#       'volume': '45',
#       'author': 'Diercks',
#       'year': '2005',
#       'journal-title': 'Ann Emerg Med'},
#      {'issue': '3',
#       'key': '10.1016/B978-0-323-39276-1.00049-4_bib65',
#       'first-page': '164',
#       'article-title': 'Chest pain in emergency department patients: if the pain is relieved by nitroglycerin, is it more likely to be cardiac chest pain?',
#       'volume': '8',
#       'author': 'Steele',
#       'year': '2006',
#       'journal-title': 'Can Assoc Emerg Phys'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib66',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1137',
#       'DOI': '10.1056/NEJM198505023121801',
#       'article-title': 'Use of the initial electrocardiogram to predict in-hospital complications of acute myocardial infarction',
#       'volume': '312',
#       'author': 'Brush',
#       'year': '1985',
#       'journal-title': 'N Engl J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib67',
#       'doi-asserted-by': 'crossref',
#       'first-page': '171',
#       'DOI': '10.1016/0002-9149(91)90739-8',
#       'article-title': 'Early prediction of acute myocardial infarction from clinical history, examination and electrocardiogram in the emergency room',
#       'volume': '68',
#       'author': 'Karlson',
#       'year': '1991',
#       'journal-title': 'Am J Cardiol'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib68',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1087',
#       'DOI': '10.1016/0002-9149(89)90857-6',
#       'article-title': 'Clinical characteristics and outcome of acute myocardial infarction in patients with initially normal or nonspecific electrocardiograms (A report from the Multicenter Chest Pain Study)',
#       'volume': '64',
#       'author': 'Rouan',
#       'year': '1989',
#       'journal-title': 'Am J Cardiol'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib69',
#       'doi-asserted-by': 'crossref',
#       'first-page': '558',
#       'DOI': '10.1002/clc.20141',
#       'article-title': 'Initial presenting electrocardiogram as determinant for hospital admission in patients presenting to the emergency department with chest pain: a pilot investigation',
#       'volume': '30',
#       'author': 'Challa',
#       'year': '2007',
#       'journal-title': 'Clin Cardiol'},
#      {'issue': 'suppl',
#       'key': '10.1016/B978-0-323-39276-1.00049-4_bib70',
#       'first-page': '8',
#       'article-title': 'A prospective evaluation of prehospital 12-lead ECG application in chest pain patients',
#       'volume': '24',
#       'author': 'Aufderheide',
#       'year': '1992',
#       'journal-title': 'J Electrocardiol'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib71',
#       'doi-asserted-by': 'crossref',
#       'first-page': '3',
#       'DOI': '10.1016/S0196-0644(98)70274-4',
#       'article-title': 'Usefulness of automated serial 12-lead ECG monitoring during the initial emergency department evaluation of patients with chest pain',
#       'volume': '31',
#       'author': 'Fesmire',
#       'year': '1998',
#       'journal-title': 'Ann Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib72',
#       'doi-asserted-by': 'crossref',
#       'first-page': '327',
#       'DOI': '10.1056/NEJM197308092890622',
#       'article-title': 'Aural sign of coronary-artery disease',
#       'volume': '289',
#       'author': 'Frank',
#       'year': '1973',
#       'journal-title': 'N Engl J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib73',
#       'doi-asserted-by': 'crossref',
#       'first-page': '247',
#       'DOI': '10.1016/0002-9343(91)90123-F',
#       'article-title': 'Increased all-cause and cardiac morbidity and mortality associated with the diagonal earlobe crease: a prospective cohort study',
#       'volume': '91',
#       'author': 'Elliott',
#       'year': '1991',
#       'journal-title': 'Am J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib74',
#       'doi-asserted-by': 'crossref',
#       'first-page': '871',
#       'DOI': '10.1111/j.1532-5415.1990.tb05702.x',
#       'article-title': 'Earlobe crease and atherosclerosis: an autopsy study',
#       'volume': '38',
#       'author': 'Ishii',
#       'year': '1990',
#       'journal-title': 'J Am Geriatr Soc'},
#      {'issue': '6',
#       'key': '10.1016/B978-0-323-39276-1.00049-4_bib75',
#       'doi-asserted-by': 'crossref',
#       'first-page': '838',
#       'DOI': '10.1016/0002-8703(65)90343-1',
#       'article-title': 'Arcus senilis and coronary artery disease',
#       'volume': '70',
#       'author': 'McAndrew',
#       'year': '1965',
#       'journal-title': 'Am Heart J'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib76',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1200',
#       'DOI': '10.2105/AJPH.80.10.1200',
#       'article-title': 'The association of corneal arcus with coronary heart disease and cardiovascular disease mortality in the Lipid Research Clinics mortality follow-up study',
#       'volume': '80',
#       'author': 'Chambless',
#       'year': '1990',
#       'journal-title': 'Am J Public Health'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib77',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1322',
#       'DOI': '10.1056/NEJM197412192912503',
#       'article-title': 'Relation of corneal arcus to cardiovascular risk factors and the incidence of coronary disease',
#       'volume': '291',
#       'author': 'Rosenman',
#       'year': '1974',
#       'journal-title': 'N Engl J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib78',
#       'first-page': '446',
#       'article-title': 'The GI cocktail in the treatment of dyspepsia: a randomized, double-blind clinical trial',
#       'volume': '8',
#       'author': 'Berman',
#       'year': '2001',
#       'journal-title': 'Acad Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib79',
#       'doi-asserted-by': 'crossref',
#       'first-page': '334',
#       'DOI': '10.1016/j.amjmed.2004.03.021',
#       'article-title': 'Bedside diagnosis of coronary artery disease: a systematic review',
#       'volume': '117',
#       'author': 'Chun',
#       'year': '2004',
#       'journal-title': 'Am J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib80',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1660',
#       'DOI': '10.1136/bmj.311.7021.1660',
#       'article-title': 'Cardiac chest pain: does body language help the diagnosis?',
#       'volume': '311',
#       'author': 'Edmondstone',
#       'year': '1995',
#       'journal-title': 'Br Med J'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib81',
#       'doi-asserted-by': 'crossref',
#       'first-page': '211',
#       'DOI': '10.1016/0002-9149(75)90003-X',
#       'article-title': 'Coronary arteriographic findings in 1000 women under age 50',
#       'volume': '35',
#       'author': 'Welch',
#       'year': '1975',
#       'journal-title': 'Am J Cardiol'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib82',
#       'doi-asserted-by': 'crossref',
#       'first-page': '647',
#       'DOI': '10.1161/01.CIR.42.4.647',
#       'article-title': 'Cinecoronary arteriography in young men',
#       'volume': '42',
#       'author': 'Welch',
#       'year': '1970',
#       'journal-title': 'Circulation'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib83',
#       'doi-asserted-by': 'crossref',
#       'first-page': '2',
#       'DOI': '10.1054/aaen.2001.0304',
#       'article-title': 'Is the radiation of chest pain a useful indicator of myocardial infarction? A prospective study of 541 patients',
#       'volume': '10',
#       'author': 'Albarran',
#       'year': '2002',
#       'journal-title': 'Accident Emerg Nurs'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib84',
#       'doi-asserted-by': 'crossref',
#       'first-page': '79',
#       'DOI': '10.1111/j.0954-6820.1971.tb07398.x',
#       'article-title': 'Pain in myocardial infarction',
#       'volume': '190',
#       'author': 'Säwe',
#       'year': '1971',
#       'journal-title': 'Acta Med Scand'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib85',
#       'doi-asserted-by': 'crossref',
#       'first-page': '129',
#       'DOI': '10.1016/j.ajem.2013.10.021',
#       'article-title': 'The new Vancouver chest pain rule using troponin as the only biomarker: an external validation study',
#       'volume': '32',
#       'author': 'Cullen',
#       'year': '2013',
#       'journal-title': 'Am J Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib86',
#       'doi-asserted-by': 'crossref',
#       'first-page': '511',
#       'DOI': '10.1016/0021-9681(67)90082-3',
#       'article-title': 'A multivariate analysis of the risk of coronary heart disease in Framingham',
#       'volume': '20',
#       'author': 'Truett',
#       'year': '1967',
#       'journal-title': 'J Chron Dis'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib87',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1267',
#       'DOI': '10.1136/bmj.327.7426.1267',
#       'article-title': 'Predictive accuracy of the Framingham coronary risk score in British men: prospective cohort study',
#       'volume': '327',
#       'author': 'Prindle',
#       'year': '2003',
#       'journal-title': 'Br Med J'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib88',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1639',
#       'DOI': '10.1111/j.1532-5415.2004.52455.x',
#       'article-title': 'The association between lipid levels and the risks of incident myocardial infarction, stroke, and total mortality: the cardiovascular health study',
#       'volume': '52',
#       'author': 'Psaty',
#       'year': '2004',
#       'journal-title': 'J Am Geriatr Soc'},
#      {'issue': '2',
#       'key': '10.1016/B978-0-323-39276-1.00049-4_bib89',
#       'doi-asserted-by': 'crossref',
#       'first-page': '180',
#       'DOI': '10.1001/jama.286.2.180',
#       'article-title': 'Validation of the Framingham coronary heart disease prediction scores: results of a multiple ethnic groups investigation',
#       'volume': '286',
#       'author': 'D’Agostino',
#       'year': '2001',
#       'journal-title': 'JAMA'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib90',
#       'doi-asserted-by': 'crossref',
#       'first-page': '687',
#       'DOI': '10.1016/S0196-0644(95)70038-2',
#       'article-title': 'Using the “GI cocktail”: a descriptive study',
#       'volume': '26',
#       'author': 'Wrenn',
#       'year': '1995',
#       'journal-title': 'Ann Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib91',
#       'doi-asserted-by': 'crossref',
#       'first-page': '981',
#       'DOI': '10.1016/S0361-1124(76)80127-X',
#       'article-title': 'Xylocaine viscous as an aid in the differential diagnosis of chest pain',
#       'volume': '5',
#       'author': 'Schwartz',
#       'year': '1976',
#       'journal-title': 'JACEP'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib92',
#       'doi-asserted-by': 'crossref',
#       'first-page': '725',
#       'DOI': '10.1016/S0196-0644(88)80623-1',
#       'article-title': 'Seizures secondary to oral viscous lidocaine',
#       'volume': '17',
#       'author': 'Hess',
#       'year': '1988',
#       'journal-title': 'Ann Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib93',
#       'doi-asserted-by': 'crossref',
#       'first-page': '245',
#       'DOI': '10.1016/0736-4679(95)02101-9',
#       'article-title': 'The GI cocktail in the evaluation of chest pain in the emergency department',
#       'volume': '14',
#       'author': 'Dickinson',
#       'year': '1996',
#       'journal-title': 'J Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib94',
#       'doi-asserted-by': 'crossref',
#       'first-page': '785',
#       'DOI': '10.1016/S0196-0644(05)81704-4',
#       'article-title': 'The emergency department treatment of dyspepsia with antacids and oral lidocaine',
#       'volume': '19',
#       'author': 'Welling',
#       'year': '1990',
#       'journal-title': 'Ann Emerg Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib95',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1498',
#       'DOI': '10.1056/NEJM199606063342303',
#       'article-title': 'Prediction of the need for intensive care in patients who come to emergency departments with acute chest pain',
#       'volume': '334',
#       'author': 'Goldman',
#       'year': '1996',
#       'journal-title': 'N Engl J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib96',
#       'doi-asserted-by': 'crossref',
#       'first-page': '285',
#       'DOI': '10.1016/S0002-9343(99)00024-8',
#       'article-title': 'Performance and potential impact of a chest pain prediction rule in a large public hospital',
#       'volume': '106',
#       'author': 'Reilly',
#       'year': '1999',
#       'journal-title': 'Am J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib97',
#       'doi-asserted-by': 'crossref',
#       'first-page': '7',
#       'DOI': '10.1016/S0002-9343(00)00640-9',
#       'article-title': 'Emergency department admissions to inpatient cardiac telemetry beds: a prospective cohort study of risk stratification and outcomes',
#       'volume': '110',
#       'author': 'Durairaj',
#       'year': '2001',
#       'journal-title': 'Am J Med'},
#      {'key': '10.1016/B978-0-323-39276-1.00049-4_bib98',
#       'doi-asserted-by': 'crossref',
#       'first-page': '1648',
#       'DOI': '10.1056/NEJM199712043372302',
#       'article-title': 'Emergency room triage of patients with acute chest pain by means of rapid testing for cardiac troponin T or troponin I',
#       'volume': '337',
#       'author': 'Hamm',
#       'year': '1997',
#       'journal-title': 'N Engl J Med'}],
#     'container-title': ['Evidence-Based Physical Diagnosis'],
#     'link': [{'URL': 'https://api.elsevier.com/content/article/PII:B9780323392761000494?httpAccept=text/xml',
#       'content-type': 'text/xml',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'https://api.elsevier.com/content/article/PII:B9780323392761000494?httpAccept=text/plain',
#       'content-type': 'text/plain',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'}],
#     'deposited': {'date-parts': [[2021, 2, 22]],
#      'date-time': '2021-02-22T18:29:26Z',
#      'timestamp': 1614018566000},
#     'score': 13.216603,
#     'resource': {'primary': {'URL': 'https://linkinghub.elsevier.com/retrieve/pii/B9780323392761000494'}},
#     'issued': {'date-parts': [[2018]]},
#     'references-count': 98,
#     'URL': 'http://dx.doi.org/10.1016/b978-0-323-39276-1.00049-4',
#     'published': {'date-parts': [[2018]]}}],
#   'items-per-page': 100,
#   'query': {'start-index': 0, 'search-terms': None}}}

# %% [markdown]
# To better understand the contents, print each of the keys.

# %%
for key in resp:
    print(key)
# Out:
# status
# message-type
# message-version
# message

# %% [markdown]
# The message key looks like it contains the most data.  Let's explore that more.

# %%
for key in resp['message']:
    print(key)
# Out:
# facets
# total-results
# items
# items-per-page
# query

# %% [markdown]
# The items key contains a lot of information, but what type is it?
# It is a list, and each element in the list is a dictionary.

# %%
print(type(resp['message']['items']))
print(type(resp['message']['items'][0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# We'll print the keys of the item dictionary to see what we want to explore next.

# %%
keys=[]
for key in resp['message']['items'][0]:
    keys.append(key)
    print(key)
# Out:
# indexed
# reference-count
# publisher
# license
# content-domain
# short-container-title
# published-print
# DOI
# type
# created
# page
# update-policy
# source
# is-referenced-by-count
# title
# prefix
# volume
# author
# member
# reference
# container-title
# language
# link
# deposited
# score
# resource
# issued
# references-count
# alternative-id
# URL
# ISSN
# issn-type
# subject
# published
# assertion

# %% [markdown]
# Let's do a more exhaustive search of the items to print the data type and value of each item.

# %%
print('Level: 0 is a list with '+str(len(resp['message']['items']))+' items.')
print('Level: 1 is a dict with '+str(len(keys))+' keys.')

for index,key in enumerate(resp['message']['items'][0]):
    print("key "+str(index)+": "+str(key))
    print("type: "+str(type(resp['message']['items'][0][key])))
    if type(resp['message']['items'][0][key])==list:
        print("values:")
        for index,value in enumerate(resp['message']['items'][0][key]):
            print("    value "+str(index)+str(value))
    elif type(resp['message']['items'][0][key])==dict:
        print("values:")
        for index,subkey in enumerate(resp['message']['items'][0][key]):
            print("    subkey "+str(index)+": "+str(subkey))
            print("    value "+str(index)+": "+str(resp['message']['items'][0][key][subkey]))
    else:
        print("value: "+str(resp['message']['items'][0][key]))
    print()
# Out:
# Level: 0 is a list with 100 items.
# Level: 1 is a dict with 35 keys.
# key 0: indexed
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2022, 6, 6]]
#     subkey 1: date-time
#     value 1: 2022-06-06T07:51:06Z
#     subkey 2: timestamp
#     value 2: 1654501866398
#
# key 1: reference-count
# type: <class 'int'>
# value: 39
#
# key 2: publisher
# type: <class 'str'>
# value: Elsevier BV
#
# key 3: license
# type: <class 'list'>
# values:
#     value 0{'start': {'date-parts': [[2016, 6, 1]], 'date-time': '2016-06-01T00:00:00Z', 'timestamp': 1464739200000}, 'content-version': 'tdm', 'delay-in-days': 0, 'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}
#
# key 4: content-domain
# type: <class 'dict'>
# values:
#     subkey 0: domain
#     value 0: ['elsevier.com', 'sciencedirect.com']
#     subkey 1: crossmark-restriction
#     value 1: True
#
# key 5: short-container-title
# type: <class 'list'>
# values:
#     value 0Journal of Economic Behavior &amp; Organization
#
# key 6: published-print
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2016, 6]]
#
# key 7: DOI
# type: <class 'str'>
# value: 10.1016/j.jebo.2016.03.001
#
# key 8: type
# type: <class 'str'>
# value: journal-article
#
# key 9: created
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2016, 3, 22]]
#     subkey 1: date-time
#     value 1: 2016-03-22T14:07:20Z
#     subkey 2: timestamp
#     value 2: 1458655640000
#
# key 10: page
# type: <class 'str'>
# value: 89-101
#
# key 11: update-policy
# type: <class 'str'>
# value: http://dx.doi.org/10.1016/elsevier_cm_policy
#
# key 12: source
# type: <class 'str'>
# value: Crossref
#
# key 13: is-referenced-by-count
# type: <class 'int'>
# value: 24
#
# key 14: title
# type: <class 'list'>
# values:
#     value 0Search, effort, and locus of control
#
# key 15: prefix
# type: <class 'str'>
# value: 10.1016
#
# key 16: volume
# type: <class 'str'>
# value: 126
#
# key 17: author
# type: <class 'list'>
# values:
#     value 0{'given': 'Andrew', 'family': 'McGee', 'sequence': 'first', 'affiliation': []}
#     value 1{'ORCID': 'http://orcid.org/0000-0002-1059-9286', 'authenticated-orcid': False, 'given': 'Peter', 'family': 'McGee', 'sequence': 'additional', 'affiliation': []}
#
# key 18: member
# type: <class 'str'>
# value: 78
#
# key 19: reference
# type: <class 'list'>
# values:
#     value 0{'key': '10.1016/j.jebo.2016.03.001_bib0005', 'series-title': 'Learning About Job Search: A Field Experiment With Job Seekers in Germany', 'author': 'Altmann', 'year': '2015'}
#     value 1{'key': '10.1016/j.jebo.2016.03.001_bib0010', 'doi-asserted-by': 'crossref', 'first-page': '308', 'DOI': '10.2307/145493', 'article-title': 'Internal–external attitudes personal initiative, and the labor market experience of black and white men', 'volume': '12', 'author': 'Andrisani', 'year': '1977', 'journal-title': 'J. Hum. Resour.'}
#     value 2{'key': '10.1016/j.jebo.2016.03.001_bib0015', 'doi-asserted-by': 'crossref', 'first-page': '658', 'DOI': '10.2307/145241', 'article-title': 'Internal–external attitudes, sense of efficacy, and labor market experience: a reply to Duncan and Morgan', 'author': 'Andrisani', 'year': '1981', 'journal-title': 'J. Hum. Resour.'}
#     value 3{'key': '10.1016/j.jebo.2016.03.001_bib0020', 'series-title': "Are Young People's Educational Outcomes Linked to Their Sense of Control?", 'author': 'Baron', 'year': '2010'}
#     value 4{'key': '10.1016/j.jebo.2016.03.001_bib0025', 'doi-asserted-by': 'crossref', 'first-page': '453', 'DOI': '10.1146/annurev-economics-080511-110922', 'article-title': 'The relationship between economic preferences and psychological personality measures', 'volume': '4', 'author': 'Becker', 'year': '2012', 'journal-title': 'Annu. Rev. Econ.'}
#     value 5{'key': '10.1016/j.jebo.2016.03.001_bib0030', 'doi-asserted-by': 'crossref', 'first-page': '103', 'DOI': '10.1006/reec.1997.0158', 'article-title': 'Unemployment, discouraged workers and female labour supply', 'volume': '52', 'author': 'Blundell', 'year': '1998', 'journal-title': 'Res. Econ.'}
#     value 6{'issue': '4', 'key': '10.1016/j.jebo.2016.03.001_bib0035', 'doi-asserted-by': 'crossref', 'first-page': '815', 'DOI': '10.3368/jhr.43.4.815', 'article-title': 'Interpersonal styles and labor market outcomes', 'volume': '43', 'author': 'Borghans', 'year': '2008', 'journal-title': 'J. Hum. Resour.'}
#     value 7{'key': '10.1016/j.jebo.2016.03.001_bib0040', 'doi-asserted-by': 'crossref', 'first-page': '155', 'DOI': '10.1257/aer.91.2.155', 'article-title': 'Incentive-enhancing preferences: personality, behavior and earnings', 'volume': '91', 'author': 'Bowles', 'year': '2001', 'journal-title': 'Am. Econ. Assoc. Pap. Proc.'}
#     value 8{'key': '10.1016/j.jebo.2016.03.001_bib0045', 'doi-asserted-by': 'crossref', 'first-page': '1', 'DOI': '10.1111/j.1465-7295.1981.tb00600.x', 'article-title': 'Economic search: an experimental study', 'volume': '19', 'author': 'Braunstein', 'year': '1981', 'journal-title': 'Econ. Inq.'}
#     value 9{'key': '10.1016/j.jebo.2016.03.001_bib0050', 'doi-asserted-by': 'crossref', 'first-page': '133', 'DOI': '10.1111/j.1465-7295.1982.tb01146.x', 'article-title': 'Labor market search: an experimental study', 'volume': '20', 'author': 'Braunstein', 'year': '1982', 'journal-title': 'Econ. Inq.'}
#     value 10{'issue': '2', 'key': '10.1016/j.jebo.2016.03.001_bib0055', 'doi-asserted-by': 'crossref', 'first-page': '948', 'DOI': '10.1257/aer.101.2.948', 'article-title': 'Real-time search in the laboratory and the market', 'volume': '101', 'author': 'Brown', 'year': '2011', 'journal-title': 'Am. Econ. Rev.'}
#     value 11{'key': '10.1016/j.jebo.2016.03.001_bib0060', 'article-title': 'Ranks of discouraged workers and others marginally attached to the labor force rise during recession', 'author': 'Bureau of Labor Statistics', 'year': '2009', 'journal-title': 'Issues Labor Stat.'}
#     value 12{'issue': '1', 'key': '10.1016/j.jebo.2016.03.001_bib0065', 'doi-asserted-by': 'crossref', 'first-page': '88', 'DOI': '10.1162/REST_a_00459', 'article-title': 'Locus of control and job search strategies', 'volume': '97', 'author': 'Caliendo', 'year': '2015', 'journal-title': 'Rev. Econ. Stat.'}
#     value 13{'key': '10.1016/j.jebo.2016.03.001_bib0070', 'series-title': 'Microeconometrics: Methods and Applications', 'author': 'Cameron', 'year': '2005'}
#     value 14{'key': '10.1016/j.jebo.2016.03.001_bib0075', 'series-title': 'Handbook of Labor Economics', 'doi-asserted-by': 'crossref', 'first-page': '229', 'DOI': '10.1016/S0169-7218(11)00409-6', 'article-title': 'Lab labor: what can labor economists learn from the lab?', 'author': 'Charness', 'year': '2011'}
#     value 15{'key': '10.1016/j.jebo.2016.03.001_bib0080', 'series-title': 'Two Economists’ Musings on the Stability of Locus of Control', 'author': 'Cobb-Clark', 'year': '2011'}
#     value 16{'key': '10.1016/j.jebo.2016.03.001_bib0085', 'doi-asserted-by': 'crossref', 'first-page': '1', 'DOI': '10.1016/j.jebo.2013.10.011', 'article-title': 'Healthy habits: the connection between diet, exercise, and locus of control', 'volume': '98', 'author': 'Cobb-Clark', 'year': '2014', 'journal-title': 'J. Econ. Behav. Organ.'}
#     value 17{'key': '10.1016/j.jebo.2016.03.001_bib0090', 'doi-asserted-by': 'crossref', 'first-page': '701', 'DOI': '10.2307/1558773', 'article-title': 'An economic model of locus of control and the human capital investment decision', 'volume': '38', 'author': 'Coleman', 'year': '2003', 'journal-title': 'J. Hum. Resour.'}
#     value 18{'key': '10.1016/j.jebo.2016.03.001_bib0095', 'doi-asserted-by': 'crossref', 'first-page': '301', 'DOI': '10.1007/BF00209391', 'article-title': 'Laboratory experiments with a finite horizon job-search model', 'volume': '2', 'author': 'Cox', 'year': '1989', 'journal-title': 'J. Risk Uncertain.'}
#     value 19{'key': '10.1016/j.jebo.2016.03.001_bib0100', 'series-title': 'The Effects of a Re-Entry Program on Locus of Control and Self-Regard', 'author': 'Dextraze', 'year': '1986'}
#     value 20{'key': '10.1016/j.jebo.2016.03.001_bib0105', 'doi-asserted-by': 'crossref', 'first-page': '379', 'DOI': '10.2466/pr0.1977.41.2.379', 'article-title': 'Effects of manipulation on examination of grades on locus of control beliefs', 'volume': '41', 'author': 'Doyle', 'year': '1977', 'journal-title': 'Psychol. Rep.'}
#     value 21{'key': '10.1016/j.jebo.2016.03.001_bib0110', 'doi-asserted-by': 'crossref', 'first-page': '352', 'DOI': '10.1037/0021-9010.78.3.352', 'article-title': 'Self-efficacy training to speed reemployment: helping people to help themselves', 'volume': '78', 'author': 'Eden', 'year': '1993', 'journal-title': 'J. Appl. Psychol.'}
#     value 22{'key': '10.1016/j.jebo.2016.03.001_bib0115', 'doi-asserted-by': 'crossref', 'first-page': '399', 'DOI': '10.1016/S0927-5371(03)00050-2', 'article-title': 'Why labour market experiments?', 'volume': '10', 'author': 'Falk', 'year': '2003', 'journal-title': 'Labour Econ.'}
#     value 23{'key': '10.1016/j.jebo.2016.03.001_bib0120', 'series-title': 'Do I Have What It Takes? Equilibrium Search With Type Uncertainty and Non-Participation', 'author': 'Falk', 'year': '2006'}
#     value 24{'issue': '4', 'key': '10.1016/j.jebo.2016.03.001_bib0125', 'doi-asserted-by': 'crossref', 'first-page': '25', 'DOI': '10.1257/089533005775196732', 'article-title': 'Cognitive reflection and decision making', 'volume': '19', 'author': 'Frederick', 'year': '2005', 'journal-title': 'J. Econ. Perspect.'}
#     value 25{'key': '10.1016/j.jebo.2016.03.001_bib0130', 'doi-asserted-by': 'crossref', 'first-page': '26', 'DOI': '10.1037/1040-3590.4.1.26', 'article-title': 'The development of markers for the Big-Five factor structure', 'volume': '4', 'author': 'Goldberg', 'year': '1992', 'journal-title': 'Psychol. Assess.'}
#     value 26{'key': '10.1016/j.jebo.2016.03.001_bib0135', 'doi-asserted-by': 'crossref', 'first-page': '815', 'DOI': '10.1111/j.1465-7295.1997.tb01966.x', 'article-title': 'The impact of psychological and human capital on wages', 'volume': '35', 'author': 'Goldsmith', 'year': '1997', 'journal-title': 'Econ. Inq.'}
#     value 27{'key': '10.1016/j.jebo.2016.03.001_bib0140', 'doi-asserted-by': 'crossref', 'first-page': '411', 'DOI': '10.1086/504455', 'article-title': 'The effects of cognitive and noncognitive abilities on labor market outcomes and social behavior', 'volume': '24', 'author': 'Heckman', 'year': '2006', 'journal-title': 'J. Labor Econ.'}
#     value 28{'issue': '5', 'key': '10.1016/j.jebo.2016.03.001_bib0145', 'doi-asserted-by': 'crossref', 'first-page': '1644', 'DOI': '10.1257/000282802762024700', 'article-title': 'Risk aversion and incentive effects', 'volume': '92', 'author': 'Holt', 'year': '2002', 'journal-title': 'Am. Econ. Rev.'}
#     value 29{'key': '10.1016/j.jebo.2016.03.001_bib0150', 'series-title': 'The College Type: Personality and Educational Inequality', 'author': 'Lundberg', 'year': '2013'}
#     value 30{'key': '10.1016/j.jebo.2016.03.001_bib0155', 'doi-asserted-by': 'crossref', 'first-page': '184', 'DOI': '10.1177/0019793914556245', 'article-title': 'How the perception of control influences unemployed job search', 'volume': '68', 'author': 'McGee', 'year': '2015', 'journal-title': 'Ind. Labor Relat. Rev.'}
#     value 31{'key': '10.1016/j.jebo.2016.03.001_bib0160', 'series-title': 'Search, Effort, and Locus of Control', 'author': 'McGee', 'year': '2011'}
#     value 32{'key': '10.1016/j.jebo.2016.03.001_bib0165', 'doi-asserted-by': 'crossref', 'first-page': '827', 'DOI': '10.1016/j.joep.2005.03.001', 'article-title': 'How important is your personality? Labor market returns to personality for women in the US and UK', 'volume': '26', 'author': 'Osborne-Groves', 'year': '2005', 'journal-title': 'J. Econ. Psychol.'}
#     value 33{'key': '10.1016/j.jebo.2016.03.001_bib0170', 'doi-asserted-by': 'crossref', 'article-title': 'Maintaining (Locus of) control? Data combination for the identification and inference of factor structure models', 'author': 'Piatek', 'year': '2015', 'journal-title': 'J. Appl. Econ.', 'DOI': '10.1002/jae.2456'}
#     value 34{'key': '10.1016/j.jebo.2016.03.001_bib0175', 'series-title': 'Society and the Adolescent Self-Image', 'author': 'Rosenberg', 'year': '1965'}
#     value 35{'issue': '1', 'key': '10.1016/j.jebo.2016.03.001_bib0180', 'doi-asserted-by': 'crossref', 'DOI': '10.1037/h0092976', 'article-title': 'Generalized expectancies for internal versus external control of reinforcement', 'volume': '80', 'author': 'Rotter', 'year': '1966', 'journal-title': 'Psychol. Monogr. Gen. Appl.'}
#     value 36{'key': '10.1016/j.jebo.2016.03.001_bib0185', 'doi-asserted-by': 'crossref', 'first-page': '1063', 'DOI': '10.1037/0022-3514.67.6.1063', 'article-title': 'Distinguishing optimism from neuroticism (and trait anxiety, self-mastery, and self-esteem): a re-evaluation of the life orientation test', 'volume': '67', 'author': 'Scheier', 'year': '1994', 'journal-title': 'J. Personal. Soc. Psychol.'}
#     value 37{'issue': '2', 'key': '10.1016/j.jebo.2016.03.001_bib0190', 'doi-asserted-by': 'crossref', 'first-page': '249', 'DOI': '10.1177/001979397402700207', 'article-title': 'The persistence of the discouraged worker effect', 'volume': '27', 'author': 'Schweitzer', 'year': '1974', 'journal-title': 'Ind. Labor Relat. Rev.'}
#     value 38{'issue': '6', 'key': '10.1016/j.jebo.2016.03.001_bib0195', 'doi-asserted-by': 'crossref', 'first-page': '685', 'DOI': '10.1037/h0056432', 'article-title': 'The personnel test: a restandardized abridgement of the Otis S-A test for business and industrial use', 'volume': '23', 'author': 'Wonderlic', 'year': '1939', 'journal-title': 'J. Appl. Psychol.'}
#
# key 20: container-title
# type: <class 'list'>
# values:
#     value 0Journal of Economic Behavior &amp; Organization
#
# key 21: language
# type: <class 'str'>
# value: en
#
# key 22: link
# type: <class 'list'>
# values:
#     value 0{'URL': 'https://api.elsevier.com/content/article/PII:S016726811630004X?httpAccept=text/xml', 'content-type': 'text/xml', 'content-version': 'vor', 'intended-application': 'text-mining'}
#     value 1{'URL': 'https://api.elsevier.com/content/article/PII:S016726811630004X?httpAccept=text/plain', 'content-type': 'text/plain', 'content-version': 'vor', 'intended-application': 'text-mining'}
#
# key 23: deposited
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2018, 9, 14]]
#     subkey 1: date-time
#     value 1: 2018-09-14T00:55:30Z
#     subkey 2: timestamp
#     value 2: 1536886530000
#
# key 24: score
# type: <class 'float'>
# value: 14.665423
#
# key 25: resource
# type: <class 'dict'>
# values:
#     subkey 0: primary
#     value 0: {'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S016726811630004X'}
#
# key 26: issued
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2016, 6]]
#
# key 27: references-count
# type: <class 'int'>
# value: 39
#
# key 28: alternative-id
# type: <class 'list'>
# values:
#     value 0S016726811630004X
#
# key 29: URL
# type: <class 'str'>
# value: http://dx.doi.org/10.1016/j.jebo.2016.03.001
#
# key 30: ISSN
# type: <class 'list'>
# values:
#     value 00167-2681
#
# key 31: issn-type
# type: <class 'list'>
# values:
#     value 0{'value': '0167-2681', 'type': 'print'}
#
# key 32: subject
# type: <class 'list'>
# values:
#     value 0Organizational Behavior and Human Resource Management
#     value 1Economics and Econometrics
#
# key 33: published
# type: <class 'dict'>
# values:
#     subkey 0: date-parts
#     value 0: [[2016, 6]]
#
# key 34: assertion
# type: <class 'list'>
# values:
#     value 0{'value': 'Elsevier', 'name': 'publisher', 'label': 'This article is maintained by'}
#     value 1{'value': 'Search, effort, and locus of control', 'name': 'articletitle', 'label': 'Article Title'}
#     value 2{'value': 'Journal of Economic Behavior & Organization', 'name': 'journaltitle', 'label': 'Journal Title'}
#     value 3{'value': 'https://doi.org/10.1016/j.jebo.2016.03.001', 'name': 'articlelink', 'label': 'CrossRef DOI link to publisher maintained version'}
#     value 4{'value': 'article', 'name': 'content_type', 'label': 'Content Type'}
#     value 5{'value': '© 2016 Elsevier B.V. All rights reserved.', 'name': 'copyright', 'label': 'Copyright'}

# %% [markdown]
# Create a list of all of the authors.

# %%
authors=[]
for index,key in enumerate(resp['message']['items']):
    authors.append(resp['message']['items'][index]['author'][0])

authors
# Out:
# [{'given': 'Andrew',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Andrew',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Department of EconomicsUniversity of Alberta Edmonton AB T6G 2H4 Canada'}]},
#  {'given': 'Glenn', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'R. G.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Andrew',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Reece', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Becky', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'W.F.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Vann', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Vann', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Kelly',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Pullman, WA. U.S.A.'}]},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'University of Central England, Birmingham, UK'}]},
#  {'given': 'P.A.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Patrick',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Timothy',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Department of Religious Studies, Southern Methodist University; P.O. Box 750133 Dallas TX 75275-0133, USA'}]},
#  {'given': 'Andrew',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Jay', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'K.J.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Brian', 'family': 'Mcgee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Terence',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'University of Central England, Birmingham, UK'}]},
#  {'given': 'W.F.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'R.X.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Hannah',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Linda',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Chief Psychologist Federal Correctional Institution\rTerminal Island, CA'}]},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Emerita Professor of Nursing, Birmingham City University, UK'}]},
#  {'given': 'Harold',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Gary', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Terry', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'O.G.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Caitlin',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Birmingham City University, Birmingham, UK'}]},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'E.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Birmingham City University, Birmingham, UK'}]},
#  {'ORCID': 'http://orcid.org/0000-0001-9150-7832',
#   'authenticated-orcid': False,
#   'given': 'Monnie',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Department of Statistical Science, Southern Methodist University, Dallas, TX'}]},
#  {'given': 'Rosemary',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'McGee', 'family': 'Young', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'W.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Vann', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'L.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Harold',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Sears', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'WilliamB.',
#   'family': 'Mcgee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Patrick',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'W.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'GLENN', 'family': 'McGEE', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Shanna',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Mick',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Usability & Interface Design Oracle Corporation Redwood Shores, California'}]},
#  {'ORCID': 'http://orcid.org/0000-0002-2772-6886',
#   'authenticated-orcid': False,
#   'given': 'Darragh',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'University of Bath, UK'}]},
#  {'given': 'B.B.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Leonard',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'James', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'J.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Micki', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Ebony',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Vanderbilt University'}]},
#  {'given': 'J.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'University of Central England'}]},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'W.F.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'T.', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Harold',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Lesley',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Glenn', 'family': 'Mcgee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Birmingham City University, Birmingham, UK'}]},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Linda',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Federal Correctional Institution Terminal Island, CA'}]},
#  {'given': 'JoAnn', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'M', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Vann', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'David', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Thomas',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Birmingham City University, Birmingham, UK'}]},
#  {'given': 'Rosemary',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Eleanor',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Paula',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Birmingham City University, Birmingham, UK'}]},
#  {'ORCID': 'http://orcid.org/0000-0003-4103-711X',
#   'authenticated-orcid': False,
#   'given': 'Corey',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Vann', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Victor',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': [{'name': 'Dartmouth College'}]},
#  {'given': 'J.Michael',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'Sears', 'family': 'McGee', 'sequence': 'first', 'affiliation': []},
#  {'given': 'Steven',
#   'family': 'McGee',
#   'sequence': 'first',
#   'affiliation': []}]

# %% [markdown]
# The variable authors is now a list of dictionaries.  We can verify that by checking the types.

# %%
print(type(authors))
print(type(authors[0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# In session 4 we will be learning more about pandas which helps create and work with dataframe objects.  Here is an example of how we could store all of the authors in a dataframe.

# %%
import pandas as pd
df_author=pd.DataFrame(list(authors))
df_author
# Out:
#         given family sequence  \
# 0      Andrew  McGee    first
# 1      Andrew  McGee    first
# 2       Glenn  McGee    first
# 3       R. G.  McGee    first
# 4      Andrew  McGee    first
# ..        ...    ...      ...
# 95       Vann  McGee    first
# 96     Victor  McGee    first
# 97  J.Michael  McGee    first
# 98      Sears  McGee    first
# 99     Steven  McGee    first
#
#                                           affiliation ORCID  \
# 0                                                  []   NaN
# 1   [{'name': 'Department of EconomicsUniversity o...   NaN
# 2                                                  []   NaN
# 3                                                  []   NaN
# 4                                                  []   NaN
# ..                                                ...   ...
# 95                                                 []   NaN
# 96                    [{'name': 'Dartmouth College'}]   NaN
# 97                                                 []   NaN
# 98                                                 []   NaN
# 99                                                 []   NaN
#
#    authenticated-orcid
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 95                 NaN
# 96                 NaN
# 97                 NaN
# 98                 NaN
# 99                 NaN
#
# [100 rows x 6 columns]
